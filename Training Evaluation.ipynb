# %% [markdown]
# # Training Evaluation

# %%
import pickle
import matplotlib.pyplot as plt

# %%
with open("training_2022-12-23_22-19-29.pkl", 'rb') as f:
    data1 = pickle.load(f)
with open("training_2022-12-24_10-29-55.pkl", 'rb') as f:
    data2 = pickle.load(f)

# %%
plt.plot(data1["history"])

# %%
plt.plot(data1["history"], alpha=0.5, label="without BiLSTM")
plt.plot(data2["history"], alpha=0.5, label="with BiLSTM")
plt.legend()
